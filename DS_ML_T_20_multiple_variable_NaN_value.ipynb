# %% [markdown]
# ![image.png](attachment:ae9df20c-cbd8-4be5-8d31-ac16a05ad1b8.png)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_excel('car_data_from_google_sheet.xlsx')
df
# Out:
#    Unnamed: 0  speed  car_age  experience  risk
# 0           0    200       15         5.0    85
# 1           1     90       17        13.0    20
# 2           2    165       12         4.0    93
# 3           3    110       20         NaN    60
# 4           4    140        5         3.0    82
# 5           5    115        2         8.0    10

# %%
df[['experience']]
# Out:
#    experience
# 0         5.0
# 1        13.0
# 2         4.0
# 3         NaN
# 4         3.0
# 5         8.0

# %%
median_value = df[['experience']].median()
median_value
# Out:
# experience    5.0
# dtype: float64

# %%
df.experience = df[['experience']].fillna(median_value)

# %%
df
# Out:
#    Unnamed: 0  speed  car_age  experience  risk
# 0           0    200       15         5.0    85
# 1           1     90       17        13.0    20
# 2           2    165       12         4.0    93
# 3           3    110       20         5.0    60
# 4           4    140        5         3.0    82
# 5           5    115        2         8.0    10

# %%
reg = LinearRegression()

# %%
reg.fit(df[['speed','car_age','experience']],df['risk'])
# Out:
# LinearRegression()

# %%
reg.predict([[160,10,5]])
# Out:
# C:\Users\islam\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([71.37146872])

# %% [markdown]
# ### Manually check by plugging in the values in t e eq: y = m1x1 + m2x2 + m3x3 + c to confirm if the model gave the right result

# %%
reg.coef_
# Out:
# array([ 0.33059217,  1.61053246, -6.20772074])

# %%
c = reg.intercept_
c
# Out:
# 33.41000091043588

# %%
y = (0.33059217 * 160) + (1.61053246 * 10) + (-6.20772074 * 5) + c
y
# Out:
# 71.37146901043589
